# %% [markdown]
# ## Introdução
#
# Este arquivo é responsável por criar um arquivo **.csv** contendo os dados de todas as 4 tabelas unidos em uma unica tabela. Este desenvolvimento foi feito no **Google Colab**, uma **IDE** de desenvolvimento de notebooks python fornecida pela **Google**.
#
# Além disso, este arquivo tratou de:
# - Excluir linhas de descrição ou legendas;
# - Excluir linhas reservadas exclusivamente para separar os alimentos por grupos alimentares;
# - Criar uma nova coluna chamada "Grupo Alimentar". Esta coluna irá receber um valor númerico que representa o grupo alimentar do alimento;
# - Atualizar o nome das colunas;
# - Mesclar todas as tabelas do arquivo **.xlsx**, conforme explicado anteriormente;
# - Criar um novo arquivo **.csv** chamado **Tabela_Taco_Atualizada.csv**

# %% [markdown]
# ## Carregando o arquivo .xlsx

# %% [markdown]
# Importando as bibliotecas Pandas e Numpy para o projeto

# %%
import pandas as pd
import numpy as np

# %%
pd.options.mode.copy_on_write = False

# %% [markdown]
# - Importando o arquivo ``.xlsx``, excel.
# - Removendo as 3 primeiras linhas inicias e as 4 ultimas linhas, pois elas não agregam em nada este trabalho de ciência de dados.
# - Adicionando a coluna "Grupo Alimentar"

# %%
url = '/content/Tabela_Taco.xlsx'
df_tabela_1 = pd.read_excel(url, skiprows=range(0,3))
df_tabela_1.drop(df_tabela_1.tail(4).index, inplace = True)
df_tabela_1
# Out:
#      Código e descrição do alimento   \
# 0              Cereais e leguminosas
# 1                            6300101
# 2                            6300201
# 3                            6300701
# 4                            6300701
# ...                              ...
# 1985                         8579003
# 1986                         8579004
# 1987                         8579005
# 1988                         8579006
# 1989                         8800109
#
#                                              Unnamed: 1  \
# 0                                                   NaN
# 1     Arroz (polido, parboilizado, agulha, agulhinha...
# 2                                        Arroz integral
# 3                                       Milho (em grão)
# 4                                       Milho (em grão)
# ...                                                 ...
# 1985                                       Maria izabel
# 1986                                     Arroz de leite
# 1987                                 Arroz com mandioca
# 1988                                      Arroz com ovo
# 1989                                             Palma
#
#       Código e descrição da preparação     Unnamed: 3 Energia (kcal)  \
# 0                                  NaN            NaN            NaN
# 1                                 99.0  Não se aplica     135.622946
# 2                                 99.0  Não se aplica     130.945644
# 3                                  1.0         Cru(a)        160.141
# 4                                  2.0      Cozido(a)        160.141
# ...                                ...            ...            ...
# 1985                              99.0  Não se aplica            154
# 1986                              99.0  Não se aplica        142.422
# 1987                              99.0  Não se aplica     130.311473
# 1988                              99.0  Não se aplica     179.106973
# 1989                              99.0  Não se aplica         41.945
#
#      Proteína\n(g) Lipídios totais\n(g) Carboi-\ndrato\n(g)  \
# 0              NaN                  NaN                 NaN
# 1         2.496113             1.200042           27.784863
# 2         2.562885             1.965797           25.556814
# 3             3.32                7.178               25.11
# 4             3.32                7.178               25.11
# ...            ...                  ...                 ...
# 1985          10.8                  7.1                11.6
# 1986          2.98                4.174              22.622
# 1987      1.548056             0.750021           28.942432
# 1988      8.085056             9.427021           14.500932
# 1989          1.35                3.098                3.28
#
#      Fibra alimentar total (g)
# 0                          NaN
# 1                     1.545702
# 2                      2.72239
# 3                         4.25
# 4                         4.25
# ...                        ...
# 1985                       1.5
# 1986                     0.303
# 1987                  1.572851
# 1988                  0.772851
# 1989                         2
#
# [1990 rows x 9 columns]

# %% [markdown]
# Fazendo o mesmo procedimento para as outras tabelas do arquivo excel

# %%
df_tabela_2 = pd.read_excel(url, skiprows=range(0,3), sheet_name=1)
df_tabela_2.drop(df_tabela_2.tail(4).index, inplace = True)

df_tabela_3 = pd.read_excel(url, skiprows=range(0,3), sheet_name=2)
df_tabela_3.drop(df_tabela_3.tail(4).index, inplace = True)

df_tabela_4 = pd.read_excel(url, skiprows=range(0,3), sheet_name=3)
df_tabela_4.drop(df_tabela_4.tail(4).index, inplace = True)

# %% [markdown]
# Criando um novo dataframe que irá possuir a coluna "Grupo Alimentar"

# %%
df_grupo_alimentar = pd.DataFrame(columns=['Grupo Alimentar'])

# %% [markdown]
# ## Lidando com os Grupos Alimentares

# %% [markdown]
# Atribuindo o valores a coluna **Grupo Alimentar**:
# - Cereais e leguminosas: 1
# - Hortaliças tuberosas: 2
# - Farinhas, féculas e massas: 3
# - Cocos, castanhas e nozes: 4
# - Hortaliças folhosas, frutosas e outras: 5
# - Frutas: 6
# - Açúcares e produtos de confeitaria: 7
# - Sais e condimentos: 8
# - Carnes e vísceras: 9
# - Pescados e frutos do mar: 10

# %%
id_grupos_alimentar = df_tabela_1[df_tabela_1['Código e descrição da preparação'].isna()].index
for i in range(0,19):
  j = i+1
  aux = 0
  if i != 18:
    aux = df_tabela_1.loc[id_grupos_alimentar[i]+1:id_grupos_alimentar[j]-1]['Código e descrição da preparação'].count()
  else:
    aux = df_tabela_1.loc[id_grupos_alimentar[i]+1:]['Código e descrição da preparação'].count()

  for k in range(0,aux):
    df_grupo_alimentar.loc[len(df_grupo_alimentar)] = {'Grupo Alimentar':j}

df_grupo_alimentar
# Out:
# i:0
# j:1
# i:1
# j:2
# i:2
# j:3
# i:3
# j:4
# i:4
# j:5
# i:5
# j:6
# i:6
# j:7
# i:7
# j:8
# i:8
# j:9
# i:9
# j:10
# i:10
# j:11
# i:11
# j:12
# i:12
# j:13
# i:13
# j:14
# i:14
# j:15
# i:15
# j:16
# i:16
# j:17
# i:17
# j:18
# i:18
# j:19
#       Grupo Alimentar
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 1966               19
# 1967               19
# 1968               19
# 1969               19
# 1970               19
#
# [1971 rows x 1 columns]

# %% [markdown]
# Excluindo as linhas que representavam os grupos alimentares

# %%
df_tabela_1.drop(id_grupos_alimentar, inplace = True)
df_tabela_2.drop(id_grupos_alimentar, inplace = True)
df_tabela_3.drop(id_grupos_alimentar, inplace = True)
df_tabela_4.drop(id_grupos_alimentar, inplace = True)
df_tabela_1
# Out:
#      Código e descrição do alimento   \
# 1                            6300101
# 2                            6300201
# 3                            6300701
# 4                            6300701
# 5                            6300701
# ...                              ...
# 1985                         8579003
# 1986                         8579004
# 1987                         8579005
# 1988                         8579006
# 1989                         8800109
#
#                                              Unnamed: 1  \
# 1     Arroz (polido, parboilizado, agulha, agulhinha...
# 2                                        Arroz integral
# 3                                       Milho (em grão)
# 4                                       Milho (em grão)
# 5                                       Milho (em grão)
# ...                                                 ...
# 1985                                       Maria izabel
# 1986                                     Arroz de leite
# 1987                                 Arroz com mandioca
# 1988                                      Arroz com ovo
# 1989                                             Palma
#
#       Código e descrição da preparação                   Unnamed: 3  \
# 1                                 99.0                Não se aplica
# 2                                 99.0                Não se aplica
# 3                                  1.0                       Cru(a)
# 4                                  2.0                    Cozido(a)
# 5                                  3.0  Grelhado(a)/brasa/churrasco
# ...                                ...                          ...
# 1985                              99.0                Não se aplica
# 1986                              99.0                Não se aplica
# 1987                              99.0                Não se aplica
# 1988                              99.0                Não se aplica
# 1989                              99.0                Não se aplica
#
#      Energia (kcal) Proteína\n(g) Lipídios totais\n(g) Carboi-\ndrato\n(g)  \
# 1        135.622946      2.496113             1.200042           27.784863
# 2        130.945644      2.562885             1.965797           25.556814
# 3           160.141          3.32                7.178               25.11
# 4           160.141          3.32                7.178               25.11
# 5           160.141          3.32                7.178               25.11
# ...             ...           ...                  ...                 ...
# 1985            154          10.8                  7.1                11.6
# 1986        142.422          2.98                4.174              22.622
# 1987     130.311473      1.548056             0.750021           28.942432
# 1988     179.106973      8.085056             9.427021           14.500932
# 1989         41.945          1.35                3.098                3.28
#
#      Fibra alimentar total (g)
# 1                     1.545702
# 2                      2.72239
# 3                         4.25
# 4                         4.25
# 5                         4.25
# ...                        ...
# 1985                       1.5
# 1986                     0.303
# 1987                  1.572851
# 1988                  0.772851
# 1989                         2
#
# [1971 rows x 9 columns]

# %% [markdown]
# ## Lidando com os nomes das colunas e mesclando as tabelas

# %%
list(df_tabela_2.columns)
# Out:
# ['Código e descrição do alimento ',
#  'Unnamed: 1',
#  'Código e descrição da preparação',
#  'Unnamed: 3',
#  'Coles-\nterol\n(mg)',
#  'AG\nSatura-\ndos\n(g)',
#  'AG\nMono \n(g)',
#  'AG\nPoli \n(g)',
#  'AG\nLino-\nléico \n(g)',
#  'AG\nLinolê-\nnico \n(g)',
#  'AG\nTrans\ntotal\n(g)',
#  'Açúcar\ntotal\n(g)',
#  'Açúcar\nde\nadição\n(g)']

# %% [markdown]
# Alterando o nome das sequintes colunas (de | para):
# - **Código e descrição do alimento** - Código do Alimento
# - **Unnamed: 1** - Descrição do Alimento
# - **Código e descrição da preparação** - Código da Preparação
# - **Unnamed: 3** - Descrição da Preparação

# %%
cols_rename = {'Código e descrição do alimento ': 'Código do alimento',
           'Unnamed: 1':'Descrição do alimento',
           'Código e descrição da preparação':'Código da preparação',
           'Unnamed: 3':'Descrição da preparação'}

df_tabela_1.rename(cols_rename, axis=1, inplace=True)
df_tabela_2.rename(cols_rename, axis=1, inplace=True)
df_tabela_3.rename(cols_rename, axis=1, inplace=True)
df_tabela_4.rename(cols_rename, axis=1, inplace=True)

df_tabela_1
# Out:
#      Código do alimento                              Descrição do alimento  \
# 1               6300101  Arroz (polido, parboilizado, agulha, agulhinha...
# 2               6300201                                     Arroz integral
# 3               6300701                                    Milho (em grão)
# 4               6300701                                    Milho (em grão)
# 5               6300701                                    Milho (em grão)
# ...                 ...                                                ...
# 1985            8579003                                       Maria izabel
# 1986            8579004                                     Arroz de leite
# 1987            8579005                                 Arroz com mandioca
# 1988            8579006                                      Arroz com ovo
# 1989            8800109                                             Palma
#
#       Código da preparação      Descrição da preparação Energia (kcal)  \
# 1                     99.0                Não se aplica     135.622946
# 2                     99.0                Não se aplica     130.945644
# 3                      1.0                       Cru(a)        160.141
# 4                      2.0                    Cozido(a)        160.141
# 5                      3.0  Grelhado(a)/brasa/churrasco        160.141
# ...                    ...                          ...            ...
# 1985                  99.0                Não se aplica            154
# 1986                  99.0                Não se aplica        142.422
# 1987                  99.0                Não se aplica     130.311473
# 1988                  99.0                Não se aplica     179.106973
# 1989                  99.0                Não se aplica         41.945
#
#      Proteína\n(g) Lipídios totais\n(g) Carboi-\ndrato\n(g)  \
# 1         2.496113             1.200042           27.784863
# 2         2.562885             1.965797           25.556814
# 3             3.32                7.178               25.11
# 4             3.32                7.178               25.11
# 5             3.32                7.178               25.11
# ...            ...                  ...                 ...
# 1985          10.8                  7.1                11.6
# 1986          2.98                4.174              22.622
# 1987      1.548056             0.750021           28.942432
# 1988      8.085056             9.427021           14.500932
# 1989          1.35                3.098                3.28
#
#      Fibra alimentar total (g)
# 1                     1.545702
# 2                      2.72239
# 3                         4.25
# 4                         4.25
# 5                         4.25
# ...                        ...
# 1985                       1.5
# 1986                     0.303
# 1987                  1.572851
# 1988                  0.772851
# 1989                         2
#
# [1971 rows x 9 columns]

# %% [markdown]
# Vamos tentar mesclar os dataframes. Vamos utilizar as colunas: **Código do alimento**, **Descrição do alimento**, **Código da preparação**, **Descrição da preparação**;

# %%
df_mesclado = pd.merge(df_tabela_1, df_tabela_2, on=['Código do alimento', 'Descrição do alimento', 'Código da preparação', 'Descrição da preparação'])
df_mesclado
# Out:
#      Código do alimento                              Descrição do alimento  \
# 0               6300101  Arroz (polido, parboilizado, agulha, agulhinha...
# 1               6300201                                     Arroz integral
# 2               6300701                                    Milho (em grão)
# 3               6300701                                    Milho (em grão)
# 4               6300701                                    Milho (em grão)
# ...                 ...                                                ...
# 1966            8579003                                       Maria izabel
# 1967            8579004                                     Arroz de leite
# 1968            8579005                                 Arroz com mandioca
# 1969            8579006                                      Arroz com ovo
# 1970            8800109                                             Palma
#
#       Código da preparação      Descrição da preparação Energia (kcal)  \
# 0                     99.0                Não se aplica     135.622946
# 1                     99.0                Não se aplica     130.945644
# 2                      1.0                       Cru(a)        160.141
# 3                      2.0                    Cozido(a)        160.141
# 4                      3.0  Grelhado(a)/brasa/churrasco        160.141
# ...                    ...                          ...            ...
# 1966                  99.0                Não se aplica            154
# 1967                  99.0                Não se aplica        142.422
# 1968                  99.0                Não se aplica     130.311473
# 1969                  99.0                Não se aplica     179.106973
# 1970                  99.0                Não se aplica         41.945
#
#      Proteína\n(g) Lipídios totais\n(g) Carboi-\ndrato\n(g)  \
# 0         2.496113             1.200042           27.784863
# 1         2.562885             1.965797           25.556814
# 2             3.32                7.178               25.11
# 3             3.32                7.178               25.11
# 4             3.32                7.178               25.11
# ...            ...                  ...                 ...
# 1966          10.8                  7.1                11.6
# 1967          2.98                4.174              22.622
# 1968      1.548056             0.750021           28.942432
# 1969      8.085056             9.427021           14.500932
# 1970          1.35                3.098                3.28
#
#      Fibra alimentar total (g) Coles-\nterol\n(mg) AG\nSatura-\ndos\n(g)  \
# 0                     1.545702                   -              0.350665
# 1                      2.72239                   -              0.449685
# 2                         4.25                   -                  1.12
# 3                         4.25                   -                  1.12
# 4                         4.25                   -                  1.12
# ...                        ...                 ...                   ...
# 1966                       1.5                  36                   3.2
# 1967                     0.303               2.744                 1.049
# 1968                  1.572851                   -              0.225333
# 1969                  0.772851             230.435              2.429833
# 1970                         2                   -                 0.483
#
#      AG\nMono \n(g) AG\nPoli \n(g) AG\nLino-\nléico \n(g)  \
# 0          0.222195       0.563118               0.556331
# 1          0.618275       0.860178               0.803881
# 2             1.718          4.009                  3.591
# 3             1.718          4.009                  3.591
# 4             1.718          4.009                  3.591
# ...             ...            ...                    ...
# 1966              3            0.2                   0.16
# 1967          0.985          1.885                  1.646
# 1968       0.161098       0.331559               0.303165
# 1969       3.024098       2.817059               2.483165
# 1970          0.701          1.781                  1.572
#
#      AG\nLinolê-\nnico \n(g) AG\nTrans\ntotal\n(g) Açúcar\ntotal\n(g)  \
# 0                   0.066209              0.005194                  -
# 1                   0.076111              0.005194                  -
# 2                      0.418                 0.031               3.16
# 3                      0.418                 0.031               3.16
# 4                      0.418                 0.031               3.16
# ...                      ...                   ...                ...
# 1966                    0.03                     -                  -
# 1967                   0.238                 0.048               1.47
# 1968                0.038104              0.002597                  -
# 1969                0.260104                0.0165              0.663
# 1970                   0.209                 0.016               1.27
#
#      Açúcar\nde\nadição\n(g)
# 0                          -
# 1                          -
# 2                          -
# 3                          -
# 4                          -
# ...                      ...
# 1966                       -
# 1967                       -
# 1968                       -
# 1969                       -
# 1970                       -
#
# [1971 rows x 18 columns]

# %%
df_mesclado = pd.merge(df_mesclado, df_tabela_3, on=['Código do alimento', 'Descrição do alimento', 'Código da preparação', 'Descrição da preparação'])
df_mesclado.head()
# Out:
#   Código do alimento                              Descrição do alimento  \
# 0            6300101  Arroz (polido, parboilizado, agulha, agulhinha...
# 1            6300201                                     Arroz integral
# 2            6300701                                    Milho (em grão)
# 3            6300701                                    Milho (em grão)
# 4            6300701                                    Milho (em grão)
#
#    Código da preparação      Descrição da preparação Energia (kcal)  \
# 0                  99.0                Não se aplica     135.622946
# 1                  99.0                Não se aplica     130.945644
# 2                   1.0                       Cru(a)        160.141
# 3                   2.0                    Cozido(a)        160.141
# 4                   3.0  Grelhado(a)/brasa/churrasco        160.141
#
#   Proteína\n(g) Lipídios totais\n(g) Carboi-\ndrato\n(g)  \
# 0      2.496113             1.200042           27.784863
# 1      2.562885             1.965797           25.556814
# 2          3.32                7.178               25.11
# 3          3.32                7.178               25.11
# 4          3.32                7.178               25.11
#
#   Fibra alimentar total (g) Coles-\nterol\n(mg)  ... Mag-\nnésio \n(mg)  \
# 0                  1.545702                   -  ...           2.231251
# 1                   2.72239                   -  ...           58.12672
# 2                      4.25                   -  ...             26.006
# 3                      4.25                   -  ...             26.006
# 4                      4.25                   -  ...             26.006
#
#   Man-\nganês \n(mg) Fósforo \n(mg) Ferro \n(mg) Sódio \n(mg)  \
# 0           0.293759      17.769139     0.076405       1.1889
# 1           0.621185     104.815641     0.259922     1.232469
# 2              0.159             75        0.445      244.964
# 3              0.159             75        0.445      244.964
# 4              0.159             75        0.445      244.964
#
#   Sódio \nde \nadição \n(mg) Potás-\nsio\n(mg) Co-\nbre \n(mg) Zinco\n(mg)  \
# 0                        382         14.529865        0.014853    0.486616
# 1                        282          74.41518        0.020134    0.676075
# 2                        245           212.051           0.047       0.611
# 3                        245           212.051           0.047       0.611
# 4                        245           212.051           0.047       0.611
#
#   Selê-\nnio\n(mcg)
# 0          0.446968
# 1          0.446968
# 2             2.904
# 3             2.904
# 4             2.904
#
# [5 rows x 29 columns]

# %%
df_mesclado = pd.merge(df_mesclado, df_tabela_4, on=['Código do alimento', 'Descrição do alimento', 'Código da preparação', 'Descrição da preparação'])
df_mesclado.head()
# Out:
#   Código do alimento                              Descrição do alimento  \
# 0            6300101  Arroz (polido, parboilizado, agulha, agulhinha...
# 1            6300201                                     Arroz integral
# 2            6300701                                    Milho (em grão)
# 3            6300701                                    Milho (em grão)
# 4            6300701                                    Milho (em grão)
#
#    Código da preparação      Descrição da preparação Energia (kcal)  \
# 0                  99.0                Não se aplica     135.622946
# 1                  99.0                Não se aplica     130.945644
# 2                   1.0                       Cru(a)        160.141
# 3                   2.0                    Cozido(a)        160.141
# 4                   3.0  Grelhado(a)/brasa/churrasco        160.141
#
#   Proteína\n(g) Lipídios totais\n(g) Carboi-\ndrato\n(g)  \
# 0      2.496113             1.200042           27.784863
# 1      2.562885             1.965797           25.556814
# 2          3.32                7.178               25.11
# 3          3.32                7.178               25.11
# 4          3.32                7.178               25.11
#
#   Fibra alimentar total (g) Coles-\nterol\n(mg)  ... Tiami-\nna\n(mg)  \
# 0                  1.545702                   -  ...                -
# 1                   2.72239                   -  ...         0.079216
# 2                      4.25                   -  ...            0.215
# 3                      4.25                   -  ...            0.215
# 4                      4.25                   -  ...            0.215
#
#   Ribofla-\nvina\n(mg) Niaci-\nna\n(mg) Niaci-\nna\n(NE)\n(mg)  \
# 0                    -                -                      -
# 1                    -                -                      -
# 2                0.072            1.614                  1.997
# 3                0.072            1.614                  1.997
# 4                0.072            1.614                  1.997
#
#   Pirido-\nxina\n(mg) Coba-\nlami-\nna\n(mcg) Folato\n(DFE)\n(mcg)  \
# 0                   -                       -                    -
# 1            0.079216                       -                    -
# 2                0.06                       -                   46
# 3                0.06                       -                   46
# 4                0.06                       -                   46
#
#   Vitami-\nna D\n(mcg) Vitami-\nna E\n(mg) Vitami-\nna C\n(mg)
# 0                    -            0.079782                   -
# 1                    -            0.079782                   -
# 2                    -               0.572                 6.2
# 3                    -               0.572                 6.2
# 4                    -               0.572                 6.2
#
# [5 rows x 41 columns]

# %% [markdown]
# Atualizando o nomes de algumas colunas que possuem \n

# %%
df_mesclado.columns
# Out:
# Index(['Código do alimento', 'Descrição do alimento', 'Código da preparação',
#        'Descrição da preparação', 'Energia (kcal)', 'Proteína\n(g)',
#        'Lipídios totais\n(g)', 'Carboi-\ndrato\n(g)',
#        'Fibra alimentar total (g)', 'Coles-\nterol\n(mg)',
#        'AG\nSatura-\ndos\n(g)', 'AG\nMono \n(g)', 'AG\nPoli \n(g)',
#        'AG\nLino-\nléico \n(g)', 'AG\nLinolê-\nnico \n(g)',
#        'AG\nTrans\ntotal\n(g)', 'Açúcar\ntotal\n(g)',
#        'Açúcar\nde\nadição\n(g)', 'Cálcio \n(mg)', 'Mag-\nnésio \n(mg)',
#        'Man-\nganês \n(mg)', 'Fósforo \n(mg)', 'Ferro \n(mg)', 'Sódio \n(mg)',
#        'Sódio \nde \nadição \n(mg)', 'Potás-\nsio\n(mg)', 'Co-\nbre \n(mg)',
#        'Zinco\n(mg)', 'Selê-\nnio\n(mcg)', 'Reti-\nnol\n(mcg)',
#        'Vitami-\nna A\n(RAE)\n(mcg)', 'Tiami-\nna\n(mg)',
#        'Ribofla-\nvina\n(mg)', 'Niaci-\nna\n(mg)', 'Niaci-\nna\n(NE)\n(mg)',
#        'Pirido-\nxina\n(mg)', 'Coba-\nlami-\nna\n(mcg)',
#        'Folato\n(DFE)\n(mcg)', 'Vitami-\nna D\n(mcg)', 'Vitami-\nna E\n(mg)',
#        'Vitami-\nna C\n(mg)'],
#       dtype='object')

# %%
cols_rename_mesclado = {
    'Proteína\n(g)' : 'Proteína (g)',
    'Lipídios totais\n(g)' : 'Lipídios totais (g)',
    'Carboi-\ndrato\n(g)' : 'Carboidrato (g)',
    'Coles-\nterol\n(mg)' : 'Colesterol (mg)',
    'AG\nSatura-\ndos\n(g)' : 'AG Saturados (g)',
    'AG\nMono \n(g)' : 'AG Mono (g)',
    'AG\nPoli \n(g)' : 'AG Poli (g)',
    'AG\nLino-\nléico \n(g)' : 'AG Linoléico (g)',
    'AG\nLinolê-\nnico \n(g)' : 'AG Linolênico (g)',
    'AG\nTrans\ntotal\n(g)' : 'AG Trans total(g)',
    'Açúcar\ntotal\n(g)': 'Açúcar total (g)',
    'Açúcar\nde\nadição\n(g)' : 'Açúcar de adição (g)',
    'Cálcio \n(mg)' : 'Cálcio (mg)',
    'Mag-\nnésio \n(mg)' : 'Magnésio (mg)',
    'Man-\nganês \n(mg)' : 'Manganês (mg)',
    'Fósforo \n(mg)' : 'Fósforo (mg)',
    'Ferro \n(mg)' : 'Ferro (mg)',
    'Sódio \n(mg)' : 'Sódio (mg)',
    'Sódio \nde \nadição \n(mg)' : 'Sódio de adição (mg)',
    'Potás-\nsio\n(mg)' : 'Potássio (mg)',
    'Co-\nbre \n(mg)' : 'Cobre (mg)',
    'Zinco\n(mg)' : 'Zinco (mg)',
    'Selê-\nnio\n(mcg)' : 'Selênio (mcg)',
    'Reti-\nnol\n(mcg)' : 'Retinol (mcg)',
    'Vitami-\nna A\n(RAE)\n(mcg)' : 'Vitamina A (RAE) (mcg)',
    'Tiami-\nna\n(mg)' : 'Tiamina (mg)',
    'Ribofla-\nvina\n(mg)' : 'Riboflavina (mg)',
    'Niaci-\nna\n(mg)' : 'Niacina (mg)',
    'Niaci-\nna\n(NE)\n(mg)' : 'Niacina (NE) (mg)',
    'Pirido-\nxina\n(mg)' : 'Piridoxina (mg)',
    'Coba-\nlami-\nna\n(mcg)' : 'Cobalamina (mcg)',
    'Folato\n(DFE)\n(mcg)' : 'Folato (DFE) (mcg)',
    'Vitami-\nna D\n(mcg)' : 'Vitamina D (mcg)',
    'Vitami-\nna E\n(mg)' : 'Vitamina E (mg)',
    'Vitami-\nna C\n(mg)' : 'Vitamina C (mg)'
}

df_mesclado.rename(cols_rename_mesclado, axis=1, inplace=True)
df_mesclado
# Out:
#      Código do alimento                              Descrição do alimento  \
# 0               6300101  Arroz (polido, parboilizado, agulha, agulhinha...
# 1               6300201                                     Arroz integral
# 2               6300701                                    Milho (em grão)
# 3               6300701                                    Milho (em grão)
# 4               6300701                                    Milho (em grão)
# ...                 ...                                                ...
# 1966            8579003                                       Maria izabel
# 1967            8579004                                     Arroz de leite
# 1968            8579005                                 Arroz com mandioca
# 1969            8579006                                      Arroz com ovo
# 1970            8800109                                             Palma
#
#       Código da preparação      Descrição da preparação Energia (kcal)  \
# 0                     99.0                Não se aplica     135.622946
# 1                     99.0                Não se aplica     130.945644
# 2                      1.0                       Cru(a)        160.141
# 3                      2.0                    Cozido(a)        160.141
# 4                      3.0  Grelhado(a)/brasa/churrasco        160.141
# ...                    ...                          ...            ...
# 1966                  99.0                Não se aplica            154
# 1967                  99.0                Não se aplica        142.422
# 1968                  99.0                Não se aplica     130.311473
# 1969                  99.0                Não se aplica     179.106973
# 1970                  99.0                Não se aplica         41.945
#
#      Proteína (g) Lipídios totais (g) Carboidrato (g)  \
# 0        2.496113            1.200042       27.784863
# 1        2.562885            1.965797       25.556814
# 2            3.32               7.178           25.11
# 3            3.32               7.178           25.11
# 4            3.32               7.178           25.11
# ...           ...                 ...             ...
# 1966         10.8                 7.1            11.6
# 1967         2.98               4.174          22.622
# 1968     1.548056            0.750021       28.942432
# 1969     8.085056            9.427021       14.500932
# 1970         1.35               3.098            3.28
#
#      Fibra alimentar total (g) Colesterol (mg)  ... Tiamina (mg)  \
# 0                     1.545702               -  ...            -
# 1                      2.72239               -  ...     0.079216
# 2                         4.25               -  ...        0.215
# 3                         4.25               -  ...        0.215
# 4                         4.25               -  ...        0.215
# ...                        ...             ...  ...          ...
# 1966                       1.5              36  ...         0.03
# 1967                     0.303           2.744  ...        0.142
# 1968                  1.572851               -  ...         0.03
# 1969                  0.772851         230.435  ...        0.036
# 1970                         2               -  ...        0.011
#
#      Riboflavina (mg) Niacina (mg) Niacina (NE) (mg) Piridoxina (mg)  \
# 0                   -            -                 -               -
# 1                   -            -                 -        0.079216
# 2               0.072        1.614             1.997            0.06
# 3               0.072        1.614             1.997            0.06
# 4               0.072        1.614             1.997            0.06
# ...               ...          ...               ...             ...
# 1966                -            -                 -            0.07
# 1967            0.068        1.183              1.93           0.077
# 1968                -            -                 -           0.015
# 1969            0.279        0.035            1.4205           0.066
# 1970             0.04        0.296             0.529           0.067
#
#      Cobalamina (mcg) Folato (DFE) (mcg) Vitamina D (mcg) Vitamina E (mg)  \
# 0                   -                  -                -        0.079782
# 1                   -                  -                -        0.079782
# 2                   -                 46                -           0.572
# 3                   -                 46                -           0.572
# 4                   -                 46                -           0.572
# ...               ...                ...              ...             ...
# 1966                -                  -                -               -
# 1967            0.121              35.38            0.274           0.297
# 1968                -                  -                -               -
# 1969           0.6035             23.913           0.6955            0.81
# 1970                -                  3                -           0.249
#
#      Vitamina C (mg)
# 0                  -
# 1                  -
# 2                6.2
# 3                6.2
# 4                6.2
# ...              ...
# 1966               -
# 1967           0.006
# 1968            5.55
# 1969               -
# 1970             5.3
#
# [1971 rows x 41 columns]

# %% [markdown]
# Adicionando a coluna **"Grupo Alimentar"** ao DataFrame **df_mesclado**

# %%
#pd.concat(df_mesclado, df_grupo_alimentar)
df_mesclado['Grupo Alimentar'] = df_grupo_alimentar
df_mesclado
# Out:
#      Código do alimento                              Descrição do alimento  \
# 0               6300101  Arroz (polido, parboilizado, agulha, agulhinha...
# 1               6300201                                     Arroz integral
# 2               6300701                                    Milho (em grão)
# 3               6300701                                    Milho (em grão)
# 4               6300701                                    Milho (em grão)
# ...                 ...                                                ...
# 1966            8579003                                       Maria izabel
# 1967            8579004                                     Arroz de leite
# 1968            8579005                                 Arroz com mandioca
# 1969            8579006                                      Arroz com ovo
# 1970            8800109                                             Palma
#
#       Código da preparação      Descrição da preparação Energia (kcal)  \
# 0                     99.0                Não se aplica     135.622946
# 1                     99.0                Não se aplica     130.945644
# 2                      1.0                       Cru(a)        160.141
# 3                      2.0                    Cozido(a)        160.141
# 4                      3.0  Grelhado(a)/brasa/churrasco        160.141
# ...                    ...                          ...            ...
# 1966                  99.0                Não se aplica            154
# 1967                  99.0                Não se aplica        142.422
# 1968                  99.0                Não se aplica     130.311473
# 1969                  99.0                Não se aplica     179.106973
# 1970                  99.0                Não se aplica         41.945
#
#      Proteína (g) Lipídios totais (g) Carboidrato (g)  \
# 0        2.496113            1.200042       27.784863
# 1        2.562885            1.965797       25.556814
# 2            3.32               7.178           25.11
# 3            3.32               7.178           25.11
# 4            3.32               7.178           25.11
# ...           ...                 ...             ...
# 1966         10.8                 7.1            11.6
# 1967         2.98               4.174          22.622
# 1968     1.548056            0.750021       28.942432
# 1969     8.085056            9.427021       14.500932
# 1970         1.35               3.098            3.28
#
#      Fibra alimentar total (g) Colesterol (mg)  ... Riboflavina (mg)  \
# 0                     1.545702               -  ...                -
# 1                      2.72239               -  ...                -
# 2                         4.25               -  ...            0.072
# 3                         4.25               -  ...            0.072
# 4                         4.25               -  ...            0.072
# ...                        ...             ...  ...              ...
# 1966                       1.5              36  ...                -
# 1967                     0.303           2.744  ...            0.068
# 1968                  1.572851               -  ...                -
# 1969                  0.772851         230.435  ...            0.279
# 1970                         2               -  ...             0.04
#
#      Niacina (mg) Niacina (NE) (mg) Piridoxina (mg) Cobalamina (mcg)  \
# 0               -                 -               -                -
# 1               -                 -        0.079216                -
# 2           1.614             1.997            0.06                -
# 3           1.614             1.997            0.06                -
# 4           1.614             1.997            0.06                -
# ...           ...               ...             ...              ...
# 1966            -                 -            0.07                -
# 1967        1.183              1.93           0.077            0.121
# 1968            -                 -           0.015                -
# 1969        0.035            1.4205           0.066           0.6035
# 1970        0.296             0.529           0.067                -
#
#      Folato (DFE) (mcg) Vitamina D (mcg) Vitamina E (mg) Vitamina C (mg)  \
# 0                     -                -        0.079782               -
# 1                     -                -        0.079782               -
# 2                    46                -           0.572             6.2
# 3                    46                -           0.572             6.2
# 4                    46                -           0.572             6.2
# ...                 ...              ...             ...             ...
# 1966                  -                -               -               -
# 1967              35.38            0.274           0.297           0.006
# 1968                  -                -               -            5.55
# 1969             23.913           0.6955            0.81               -
# 1970                  3                -           0.249             5.3
#
#      Grupo Alimentar
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 1966              19
# 1967              19
# 1968              19
# 1969              19
# 1970              19
#
# [1971 rows x 42 columns]

# %% [markdown]
# ## Criando o arquivo .csv

# %% [markdown]
# Verificando se não ficou nenhum dado nulo ou nan

# %%
df_mesclado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1971 entries, 0 to 1970
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código do alimento         1971 non-null   object
#  1   Descrição do alimento      1971 non-null   object
#  2   Código da preparação       1971 non-null   float64
#  3   Descrição da preparação    1971 non-null   object
#  4   Energia (kcal)             1971 non-null   object
#  5   Proteína (g)               1971 non-null   object
#  6   Lipídios totais (g)        1971 non-null   object
#  7   Carboidrato (g)            1971 non-null   object
#  8   Fibra alimentar total (g)  1971 non-null   object
#  9   Colesterol (mg)            1971 non-null   object
#  10  AG Saturados (g)           1971 non-null   object
#  11  AG Mono (g)                1971 non-null   object
#  12  AG Poli (g)                1971 non-null   object
#  13  AG Linoléico (g)           1971 non-null   object
#  14  AG Linolênico (g)          1971 non-null   object
#  15  AG Trans total(g)          1971 non-null   object
#  16  Açúcar total (g)           1971 non-null   object
#  17  Açúcar de adição (g)       1971 non-null   object
#  18  Cálcio (mg)                1971 non-null   object
#  19  Magnésio (mg)              1971 non-null   object
#  20  Manganês (mg)              1971 non-null   object
#  21  Fósforo (mg)               1971 non-null   object
#  22  Ferro (mg)                 1971 non-null   object
#  23  Sódio (mg)                 1971 non-null   object
#  24  Sódio de adição (mg)       1971 non-null   object
#  25  Potássio (mg)              1971 non-null   object
#  26  Cobre (mg)                 1971 non-null   object
#  27  Zinco (mg)                 1971 non-null   object
#  28  Selênio (mcg)              1971 non-null   object
#  29  Retinol (mcg)              1971 non-null   object
#  30  Vitamina A (RAE) (mcg)     1971 non-null   object
#  31  Tiamina (mg)               1971 non-null   object
#  32  Riboflavina (mg)           1971 non-null   object
#  33  Niacina (mg)               1971 non-null   object
#  34  Niacina (NE) (mg)          1971 non-null   object
#  35  Piridoxina (mg)            1971 non-null   object
#  36  Cobalamina (mcg)           1971 non-null   object
#  37  Folato (DFE) (mcg)         1971 non-null   object
#  38  Vitamina D (mcg)           1971 non-null   object
#  39  Vitamina E (mg)            1971 non-null   object
#  40  Vitamina C (mg)            1971 non-null   object
#  41  Grupo Alimentar            1971 non-null   int64
# dtypes: float64(1), int64(1), object(40)
# memory usage: 646.9+ KB

# %% [markdown]
# Criando um arquivo **.csv** com os dados mesclados e atualizados.

# %%
df_mesclado.to_csv('Tabela_Taco_Atualizada.csv', index=False)
